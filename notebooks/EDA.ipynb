# %%
import os
import sys
import pandas as pd

sys.path.append(os.path.abspath('../scripts'))
from load_data import load_data_from_txt, save_to_csv

# %%
input_filepath= 'MachineLearningRating_v3.txt'
output_filepathh = 'MachineLearningRating_v3.csv'

load_data_from_txt(input_filepath, output_filepathh)
# Out:
# c:\Users\Tsega KisPay\Documents\GitHub\KF-AlphaCare-Insurance-Analytics\scripts\load_data.py:13: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(input_filepath, delimiter='|')
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# ...

# %%
data = load_data(output_filepathh)
# Out:
# c:\Users\Tsega KisPay\Documents\GitHub\KF-AlphaCare-Insurance-Analytics\scripts\data_overview.py:9: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(filepath)

# %%
check_missing_values(data)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
plot_histogram(data, "TotalPremium")
